# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
import warnings
from urllib3.exceptions import InsecureRequestWarning

# Tắt cảnh báo SSL không xác thực
warnings.filterwarnings('ignore', category=InsecureRequestWarning)

# Danh sách User-Agent giả lập trình duyệt để tránh bị chặn
user_agents = [
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
]

headers = {'User-Agent': random.choice(user_agents)}
session = requests.Session()

# Lấy nội dung văn bản từ trang web
def fetch_page_text(url, retries=3, timeout=5):
    attempt = 0
    while attempt < retries:
        try:
            response = session.get(url, timeout=timeout, headers=headers, verify=False)
            response.raise_for_status()
            soup = BeautifulSoup(response.content, 'html.parser')
            return soup.get_text(separator='\n', strip=True)
        except requests.exceptions.RequestException:
            attempt += 1
            time.sleep(1)
    return None

# Crawl dữ liệu từ danh sách URL
def crawl_urls(url_list):
    results = {}
    for index, url in enumerate(url_list):
        print(f"Fetching: {url}")
        text = fetch_page_text(url)
        if text:
            results[url] = text
        else:
            print(f"Failed to crawl: {url}")
    return results

# Lưu dữ liệu đã crawl thành các file .txt
def save_crawled_data(crawled_data, urls):
    for index, url in enumerate(urls):
        text = crawled_data.get(url, "")
        cleaned_text = text.replace('\n', ' ')
        output_file = f"C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/{index}.txt"
        with open(output_file, 'w', encoding='utf-8') as file:
            file.write(cleaned_text)
        print(f"Saved: {output_file}")

# Main script
if __name__ == "__main__":
    file_path = r'C:\Users\Admin\Documents\python project\End-to-end-NLP-System-Building-ASM\data\data_source.csv'
    data = pd.read_csv(file_path)

    # Nếu chỉ có 1 cột chứa URL thì dùng cột đầu tiên:
    if 'Source URL' in data.columns:
        urls = data['Source URL'].dropna().str.strip().unique()
    else:
        urls = data.iloc[:, 0].dropna().str.strip().unique()

    # Bắt đầu crawl
    crawled_data = crawl_urls(urls)

    # Lưu kết quả
    save_crawled_data(crawled_data, urls)

    print("✅ Crawling complete!")
# Out:
# Fetching: https://www.vnu.edu.vn
# Fetching: https://vnuhn.edu.vn
# Failed to crawl: https://vnuhn.edu.vn
# Fetching: https://vnu.edu.vn/home/?C1916%2FN4%2FLich-su-hinh-thanh.htm
# Fetching: https://vi.wikipedia.org/wiki/Đại_học_Quốc_gia_Hà_Nội
# Fetching: https://daibieunhandan.vn/hanh-trinh-30-nam-phat-trien-khang-dinh-vi-the-trong-nuoc-va-quoc-te-cua-dai-hoc-quoc-gia-ha-noi-10324520.html
# Fetching: https://tuyensinh.vnu.edu.vn
# Fetching: https://vnu.edu.vn/ttsk/?C2495%2FN34669%2FThong-tin-tuyen-sinh-dai-hoc-chinh-quy-nam-2024-cua-dHQGHN.htm
# Fetching: https://tuyensinhso.vn/school/dai-hoc-cong-nghe-dai-hoc-quoc-gia-ha-noi.html
# Fetching: https://vnu.edu.vn/btdhqghn/?C2090%2FN31981%2FQuy-che%CC%81-da%CC%80o-ta%CC%A3o-da%CC%A3i-ho%CC%A3c-tai-dHQGHN.htm
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/43.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/44.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/45.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/46.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/47.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/48.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/49.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/50.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/51.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/52.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/53.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/54.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/55.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/56.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/57.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/58.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/59.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/60.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/61.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/62.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/63.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/64.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/65.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/66.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/67.txt
# Saved: C:/Users/Admin/Documents/python project/End-to-end-NLP-System-Building-ASM/data/crawled_text_datas/68.txt
# ✅ Crawling complete!
